# %%
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy

# Load data
data = Dataset.load_builtin('ml-100k')  # or use custom
trainset, testset = train_test_split(data, test_size=0.2)

# Build model
model = SVD()
model.fit(trainset)

# Predict
predictions = model.test(testset)
print("RMSE:", accuracy.rmse(predictions))
# Out:
# Dataset ml-100k could not be found. Do you want to download it? [Y/n] y
# Trying to download dataset from https://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to /root/.surprise_data/ml-100k
# RMSE: 0.9376
# RMSE: 0.9375850226698285

# %%
predictions
# Out:
# [Prediction(uid='532', iid='562', r_ui=5.0, est=4.086762158083162, details={'was_impossible': False}),
#  Prediction(uid='321', iid='199', r_ui=4.0, est=3.9872109179505917, details={'was_impossible': False}),
#  Prediction(uid='887', iid='128', r_ui=5.0, est=4.210917616023712, details={'was_impossible': False}),
#  Prediction(uid='617', iid='175', r_ui=4.0, est=3.490874169142219, details={'was_impossible': False}),
#  Prediction(uid='405', iid='186', r_ui=5.0, est=2.604106762689269, details={'was_impossible': False}),
#  Prediction(uid='713', iid='689', r_ui=3.0, est=2.6502923156183806, details={'was_impossible': False}),
#  Prediction(uid='866', iid='305', r_ui=2.0, est=2.94187534882517, details={'was_impossible': False}),
#  Prediction(uid='308', iid='477', r_ui=4.0, est=3.15114666904996, details={'was_impossible': False}),
#  Prediction(uid='537', iid='371', r_ui=3.0, est=2.845665788114302, details={'was_impossible': False}),
#  Prediction(uid='333', iid='153', r_ui=4.0, est=3.8970259051952976, details={'was_impossible': False}),
#  Prediction(uid='749', iid='239', r_ui=4.0, est=3.9141065197575196, details={'was_impossible': False}),
#  Prediction(uid='174', iid='471', r_ui=5.0, est=3.3611442315666604, details={'was_impossible': False}),
#  Prediction(uid='416', iid='4', r_ui=4.0, est=4.231576779500184, details={'was_impossible': False}),
#  Prediction(uid='586', iid='182', r_ui=3.0, est=3.574482401555891, details={'was_impossible': False}),
#  Prediction(uid='432', iid='111', r_ui=4.0, est=3.5607958961015753, details={'was_impossible': False}),
#  Prediction(uid='109', iid='928', r_ui=3.0, est=3.292904198124246, details={'was_impossible': False}),
#  Prediction(uid='95', iid='182', r_ui=2.0, est=3.6021614557844432, details={'was_impossible': False}),
#  Prediction(uid='927', iid='775', r_ui=3.0, est=2.9682681333130194, details={'was_impossible': False}),
#  Prediction(uid='304', iid='310', r_ui=3.0, est=3.8212493867728865, details={'was_impossible': False}),
#  Prediction(uid='276', iid='117', r_ui=4.0, est=3.489972399606306, details={'was_impossible': False}),
#  Prediction(uid='922', iid='406', r_ui=4.0, est=2.0379034543029984, details={'was_impossible': False}),
#  Prediction(uid='276', iid='154', r_ui=4.0, est=3.890160940451813, details={'was_impossible': False}),
#  Prediction(uid='13', iid='451', r_ui=1.0, est=3.683712122510429, details={'was_impossible': False}),
#  Prediction(uid='141', iid='591', r_ui=4.0, est=4.0106577449062755, details={'was_impossible': False}),
#  Prediction(uid='501', iid='1014', r_ui=4.0, est=3.2657584864320865, details={'was_impossible': False}),
#  Prediction(uid='589', iid='332', r_ui=4.0, est=3.589583313368867, details={'was_impossible': False}),
#  Prediction(uid='765', iid='151', r_ui=4.0, est=3.5027839507235243, details={'was_impossible': False}),
#  Prediction(uid='301', iid='373', r_ui=4.0, est=2.587084427264495, details={'was_impossible': False}),
#  Prediction(uid='87', iid='152', r_ui=4.0, est=3.6564414166753476, details={'was_impossible': False}),
#  Prediction(uid='246', iid='294', r_ui=2.0, est=2.76534441108559, details={'was_impossible': False}),
#  Prediction(uid='189', iid='10', r_ui=5.0, est=4.3975732098806315, details={'was_impossible': False}),
#  Prediction(uid='18', iid='8', r_ui=5.0, est=3.8562760956063253, details={'was_impossible': False}),
#  Prediction(uid='14', iid='276', r_ui=4.0, est=3.6649593217742047, details={'was_impossible': False}),
#  Prediction(uid='109', iid='1011', r_ui=3.0, est=3.064073597130315, details={'was_impossible': False}),
#  Prediction(uid='30', iid='683', r_ui=3.0, est=3.077483303801912, details={'was_impossible': False}),
#  Prediction(uid='255', iid='147', r_ui=4.0, est=2.7579557701050983, details={'was_impossible': False}),
#  Prediction(uid='330', iid='38', r_ui=4.0, est=3.998485864404469, details={'was_impossible': False}),
#  Prediction(uid='406', iid='190', r_ui=5.0, est=4.069428274825649, details={'was_impossible': False}),
#  Prediction(uid='387', iid='205', r_ui=5.0, est=4.315315034041735, details={'was_impossible': False}),
#  Prediction(uid='1', iid='50', r_ui=5.0, est=4.953565988876728, details={'was_impossible': False}),
#  Prediction(uid='790', iid='825', r_ui=3.0, est=2.8372007081748367, details={'was_impossible': False}),
#  Prediction(uid='130', iid='42', r_ui=4.0, est=4.127374102887155, details={'was_impossible': False}),
#  Prediction(uid='679', iid='419', r_ui=3.0, est=3.616591751989103, details={'was_impossible': False}),
#  Prediction(uid='928', iid='876', r_ui=5.0, est=3.3883955391160434, details={'was_impossible': False}),
#  Prediction(uid='327', iid='164', r_ui=3.0, est=3.5384558183270736, details={'was_impossible': False}),
#  Prediction(uid='650', iid='179', r_ui=2.0, est=3.4178647858434057, details={'was_impossible': False}),
#  Prediction(uid='293', iid='412', r_ui=1.0, est=2.2009161169837794, details={'was_impossible': False}),
#  Prediction(uid='343', iid='179', r_ui=5.0, est=4.114665749836057, details={'was_impossible': False}),
#  Prediction(uid='325', iid='269', r_ui=4.0, est=3.6940514413434657, details={'was_impossible': False}),
#  Prediction(uid='181', iid='260', r_ui=1.0, est=1, details={'was_impossible': False}),
#  Prediction(uid='153', iid='22', r_ui=2.0, est=3.5009066818370913, details={'was_impossible': False}),
#  Prediction(uid='89', iid='236', r_ui=5.0, est=4.480119725009709, details={'was_impossible': False}),
#  Prediction(uid='585', iid='1512', r_ui=5.0, est=3.703909248548195, details={'was_impossible': False}),
#  Prediction(uid='160', iid='544', r_ui=4.0, est=3.455112501163892, details={'was_impossible': False}),
#  Prediction(uid='707', iid='116', r_ui=5.0, est=4.166422925104273, details={'was_impossible': False}),
#  Prediction(uid='559', iid='902', r_ui=4.0, est=3.7332169373656714, details={'was_impossible': False}),
#  Prediction(uid='655', iid='794', r_ui=1.0, est=2.8747611586542576, details={'was_impossible': False}),
#  Prediction(uid='437', iid='418', r_ui=3.0, est=3.6563841868620894, details={'was_impossible': False}),
#  Prediction(uid='868', iid='946', r_ui=1.0, est=2.9495562451447372, details={'was_impossible': False}),
#  Prediction(uid='843', iid='300', r_ui=3.0, est=2.7713608618190384, details={'was_impossible': False}),
#  Prediction(uid='627', iid='125', r_ui=2.0, est=2.782599712343735, details={'was_impossible': False}),
#  Prediction(uid='601', iid='318', r_ui=4.0, est=4.0994106940277995, details={'was_impossible': False}),
#  Prediction(uid='329', iid='300', r_ui=4.0, est=2.836769840514405, details={'was_impossible': False}),
#  Prediction(uid='886', iid='940', r_ui=2.0, est=2.3638219568767203, details={'was_impossible': False}),
#  Prediction(uid='416', iid='421', r_ui=5.0, est=3.6164334321759237, details={'was_impossible': False}),
#  Prediction(uid='851', iid='1009', r_ui=2.0, est=3.404163490276515, details={'was_impossible': False}),
#  Prediction(uid='224', iid='704', r_ui=3.0, est=2.6480364089270663, details={'was_impossible': False}),
#  Prediction(uid='825', iid='9', r_ui=3.0, est=3.5578415570145063, details={'was_impossible': False}),
#  Prediction(uid='655', iid='739', r_ui=4.0, est=2.482228229648876, details={'was_impossible': False}),
#  Prediction(uid='471', iid='1219', r_ui=4.0, est=2.4256506840276897, details={'was_impossible': False}),
#  Prediction(uid='188', iid='173', r_ui=5.0, est=4.16422279896684, details={'was_impossible': False}),
#  Prediction(uid='346', iid='172', r_ui=5.0, est=4.186946143981994, details={'was_impossible': False}),
#  Prediction(uid='551', iid='1621', r_ui=1.0, est=3.6992700632468005, details={'was_impossible': False}),
#  Prediction(uid='491', iid='273', r_ui=5.0, est=3.2292224628255926, details={'was_impossible': False}),
#  Prediction(uid='457', iid='222', r_ui=5.0, est=4.588720763350966, details={'was_impossible': False}),
#  Prediction(uid='796', iid='692', r_ui=5.0, est=4.197618905359892, details={'was_impossible': False}),
#  Prediction(uid='269', iid='582', r_ui=4.0, est=3.4936323414481434, details={'was_impossible': False}),
#  Prediction(uid='766', iid='95', r_ui=3.0, est=3.306086710954718, details={'was_impossible': False}),
#  Prediction(uid='201', iid='1355', r_ui=1.0, est=3.0664214293136274, details={'was_impossible': False}),
#  Prediction(uid='48', iid='654', r_ui=5.0, est=4.0489495211812905, details={'was_impossible': False}),
#  Prediction(uid='184', iid='506', r_ui=4.0, est=4.023315914608499, details={'was_impossible': False}),
#  Prediction(uid='327', iid='1007', r_ui=4.0, est=3.793050894158783, details={'was_impossible': False}),
#  Prediction(uid='275', iid='825', r_ui=2.0, est=2.741847983808519, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1086', r_ui=1.0, est=1.8227559019606816, details={'was_impossible': False}),
#  Prediction(uid='363', iid='919', r_ui=5.0, est=3.8009749918387077, details={'was_impossible': False}),
#  Prediction(uid='577', iid='651', r_ui=5.0, est=4.539302256284891, details={'was_impossible': False}),
#  Prediction(uid='380', iid='183', r_ui=4.0, est=3.2923326591793094, details={'was_impossible': False}),
#  Prediction(uid='313', iid='651', r_ui=3.0, est=3.9998281545276972, details={'was_impossible': False}),
#  Prediction(uid='276', iid='636', r_ui=4.0, est=3.465434473021587, details={'was_impossible': False}),
#  Prediction(uid='690', iid='636', r_ui=4.0, est=2.891520409672275, details={'was_impossible': False}),
#  Prediction(uid='655', iid='1008', r_ui=3.0, est=2.6390464509677933, details={'was_impossible': False}),
#  Prediction(uid='806', iid='153', r_ui=4.0, est=3.871627950881294, details={'was_impossible': False}),
#  Prediction(uid='932', iid='570', r_ui=4.0, est=3.2875745985353184, details={'was_impossible': False}),
#  Prediction(uid='178', iid='127', r_ui=5.0, est=4.046443825628885, details={'was_impossible': False}),
#  Prediction(uid='820', iid='748', r_ui=1.0, est=2.7119145058812735, details={'was_impossible': False}),
#  Prediction(uid='194', iid='196', r_ui=3.0, est=3.3836198123393753, details={'was_impossible': False}),
#  Prediction(uid='178', iid='1300', r_ui=3.0, est=2.7596914212661003, details={'was_impossible': False}),
#  Prediction(uid='430', iid='294', r_ui=2.0, est=3.2818645056935147, details={'was_impossible': False}),
#  Prediction(uid='57', iid='475', r_ui=2.0, est=4.024225672862144, details={'was_impossible': False}),
#  Prediction(uid='407', iid='1', r_ui=4.0, est=3.7021787019062127, details={'was_impossible': False}),
#  Prediction(uid='601', iid='482', r_ui=4.0, est=3.5002556587743126, details={'was_impossible': False}),
#  Prediction(uid='650', iid='159', r_ui=3.0, est=2.6915829580404536, details={'was_impossible': False}),
#  Prediction(uid='767', iid='170', r_ui=5.0, est=4.60977294985184, details={'was_impossible': False}),
#  Prediction(uid='291', iid='153', r_ui=4.0, est=4.360349695949946, details={'was_impossible': False}),
#  Prediction(uid='452', iid='480', r_ui=5.0, est=4.387729635408833, details={'was_impossible': False}),
#  Prediction(uid='253', iid='318', r_ui=5.0, est=4.992822504635506, details={'was_impossible': False}),
#  Prediction(uid='658', iid='960', r_ui=4.0, est=3.57500980519594, details={'was_impossible': False}),
#  Prediction(uid='741', iid='288', r_ui=4.0, est=3.5380807393055838, details={'was_impossible': False}),
#  Prediction(uid='293', iid='82', r_ui=4.0, est=3.0485131838036468, details={'was_impossible': False}),
#  Prediction(uid='916', iid='470', r_ui=3.0, est=3.617594037471499, details={'was_impossible': False}),
#  Prediction(uid='666', iid='197', r_ui=4.0, est=4.152362035096377, details={'was_impossible': False}),
#  Prediction(uid='269', iid='1091', r_ui=2.0, est=2.014722404436474, details={'was_impossible': False}),
#  Prediction(uid='213', iid='627', r_ui=4.0, est=3.681536788254818, details={'was_impossible': False}),
#  Prediction(uid='887', iid='768', r_ui=4.0, est=4.278686069265845, details={'was_impossible': False}),
#  Prediction(uid='303', iid='475', r_ui=4.0, est=4.798680262641417, details={'was_impossible': False}),
#  Prediction(uid='707', iid='449', r_ui=2.0, est=2.6426043621368587, details={'was_impossible': False}),
#  Prediction(uid='130', iid='761', r_ui=3.0, est=3.513526690607119, details={'was_impossible': False}),
#  Prediction(uid='128', iid='949', r_ui=4.0, est=3.233690498161124, details={'was_impossible': False}),
#  Prediction(uid='83', iid='1049', r_ui=3.0, est=2.5081038435359253, details={'was_impossible': False}),
#  Prediction(uid='279', iid='388', r_ui=3.0, est=2.232476131318122, details={'was_impossible': False}),
#  Prediction(uid='666', iid='855', r_ui=4.0, est=3.6831312042411963, details={'was_impossible': False}),
#  Prediction(uid='336', iid='276', r_ui=4.0, est=3.6342795940592394, details={'was_impossible': False}),
#  Prediction(uid='26', iid='979', r_ui=3.0, est=2.7909739020061775, details={'was_impossible': False}),
#  Prediction(uid='158', iid='148', r_ui=4.0, est=3.567461255057025, details={'was_impossible': False}),
#  Prediction(uid='465', iid='50', r_ui=4.0, est=3.665155383307617, details={'was_impossible': False}),
#  Prediction(uid='293', iid='143', r_ui=4.0, est=2.7608721742324596, details={'was_impossible': False}),
#  Prediction(uid='142', iid='7', r_ui=4.0, est=3.778307930756894, details={'was_impossible': False}),
#  Prediction(uid='126', iid='286', r_ui=3.0, est=3.512049040528838, details={'was_impossible': False}),
#  Prediction(uid='593', iid='775', r_ui=3.0, est=3.142975485627105, details={'was_impossible': False}),
#  Prediction(uid='817', iid='15', r_ui=3.0, est=3.437728370504046, details={'was_impossible': False}),
#  Prediction(uid='120', iid='15', r_ui=4.0, est=3.829220973885404, details={'was_impossible': False}),
#  Prediction(uid='706', iid='7', r_ui=3.0, est=3.931019705459972, details={'was_impossible': False}),
#  Prediction(uid='409', iid='195', r_ui=4.0, est=3.471546740176802, details={'was_impossible': False}),
#  Prediction(uid='774', iid='418', r_ui=2.0, est=1.8852665743863772, details={'was_impossible': False}),
#  Prediction(uid='934', iid='492', r_ui=4.0, est=3.6918443360703193, details={'was_impossible': False}),
#  Prediction(uid='279', iid='137', r_ui=4.0, est=3.1011226869144433, details={'was_impossible': False}),
#  Prediction(uid='496', iid='98', r_ui=4.0, est=3.708841977233924, details={'was_impossible': False}),
#  Prediction(uid='106', iid='100', r_ui=3.0, est=4.244673295517602, details={'was_impossible': False}),
#  Prediction(uid='168', iid='871', r_ui=3.0, est=2.8327138631233524, details={'was_impossible': False}),
#  Prediction(uid='527', iid='187', r_ui=5.0, est=3.9962257629115516, details={'was_impossible': False}),
#  Prediction(uid='600', iid='29', r_ui=2.0, est=2.799581840776162, details={'was_impossible': False}),
#  Prediction(uid='600', iid='182', r_ui=4.0, est=4.482642313578026, details={'was_impossible': False}),
#  Prediction(uid='499', iid='902', r_ui=5.0, est=3.936598186594223, details={'was_impossible': False}),
#  Prediction(uid='593', iid='255', r_ui=5.0, est=3.5358437124896898, details={'was_impossible': False}),
#  Prediction(uid='870', iid='95', r_ui=4.0, est=3.1699353448712193, details={'was_impossible': False}),
#  Prediction(uid='178', iid='8', r_ui=4.0, est=3.8636278525247127, details={'was_impossible': False}),
#  Prediction(uid='255', iid='258', r_ui=4.0, est=3.2125135170636314, details={'was_impossible': False}),
#  Prediction(uid='655', iid='344', r_ui=4.0, est=2.9073714743987935, details={'was_impossible': False}),
#  Prediction(uid='633', iid='237', r_ui=4.0, est=3.163987670508266, details={'was_impossible': False}),
#  Prediction(uid='436', iid='219', r_ui=5.0, est=3.3616940734524112, details={'was_impossible': False}),
#  Prediction(uid='222', iid='717', r_ui=1.0, est=2.5368320152670316, details={'was_impossible': False}),
#  Prediction(uid='504', iid='739', r_ui=3.0, est=3.8025502885237117, details={'was_impossible': False}),
#  Prediction(uid='942', iid='705', r_ui=4.0, est=4.365014918815568, details={'was_impossible': False}),
#  Prediction(uid='230', iid='693', r_ui=2.0, est=3.903108313188779, details={'was_impossible': False}),
#  Prediction(uid='843', iid='186', r_ui=2.0, est=3.190431910711824, details={'was_impossible': False}),
#  Prediction(uid='642', iid='417', r_ui=3.0, est=3.4852374774634303, details={'was_impossible': False}),
#  Prediction(uid='712', iid='90', r_ui=3.0, est=3.5077582693630376, details={'was_impossible': False}),
#  Prediction(uid='387', iid='214', r_ui=5.0, est=3.300020962482458, details={'was_impossible': False}),
#  Prediction(uid='488', iid='28', r_ui=4.0, est=3.7971707310796385, details={'was_impossible': False}),
#  Prediction(uid='269', iid='531', r_ui=5.0, est=3.0028432847867585, details={'was_impossible': False}),
#  Prediction(uid='795', iid='174', r_ui=4.0, est=3.5654761234470764, details={'was_impossible': False}),
#  Prediction(uid='586', iid='237', r_ui=4.0, est=3.636144342802947, details={'was_impossible': False}),
#  Prediction(uid='682', iid='932', r_ui=1.0, est=2.7723072448955133, details={'was_impossible': False}),
#  Prediction(uid='398', iid='167', r_ui=3.0, est=3.1307868887601127, details={'was_impossible': False}),
#  Prediction(uid='865', iid='1240', r_ui=5.0, est=2.821087084705336, details={'was_impossible': False}),
#  Prediction(uid='483', iid='199', r_ui=3.0, est=3.6661086557466085, details={'was_impossible': False}),
#  Prediction(uid='347', iid='182', r_ui=5.0, est=4.020392725943556, details={'was_impossible': False}),
#  Prediction(uid='416', iid='535', r_ui=4.0, est=3.6595078433903896, details={'was_impossible': False}),
#  Prediction(uid='548', iid='237', r_ui=4.0, est=3.8830625408158377, details={'was_impossible': False}),
#  Prediction(uid='639', iid='990', r_ui=1.0, est=2.213024129876083, details={'was_impossible': False}),
#  Prediction(uid='207', iid='175', r_ui=1.0, est=3.2483733433726467, details={'was_impossible': False}),
#  Prediction(uid='394', iid='771', r_ui=4.0, est=2.8965634157274893, details={'was_impossible': False}),
#  Prediction(uid='286', iid='215', r_ui=3.0, est=3.907053493104693, details={'was_impossible': False}),
#  Prediction(uid='269', iid='412', r_ui=3.0, est=2.450557064388227, details={'was_impossible': False}),
#  Prediction(uid='739', iid='132', r_ui=4.0, est=4.039210988600046, details={'was_impossible': False}),
#  Prediction(uid='181', iid='473', r_ui=2.0, est=1.6506709735774898, details={'was_impossible': False}),
#  Prediction(uid='707', iid='485', r_ui=4.0, est=3.351895481184721, details={'was_impossible': False}),
#  Prediction(uid='308', iid='134', r_ui=5.0, est=4.256732966324115, details={'was_impossible': False}),
#  Prediction(uid='624', iid='595', r_ui=3.0, est=3.258915785285525, details={'was_impossible': False}),
#  Prediction(uid='137', iid='411', r_ui=5.0, est=3.9489147671465155, details={'was_impossible': False}),
#  Prediction(uid='216', iid='367', r_ui=3.0, est=3.647485577455036, details={'was_impossible': False}),
#  Prediction(uid='902', iid='993', r_ui=3.0, est=3.1664615264864837, details={'was_impossible': False}),
#  Prediction(uid='339', iid='186', r_ui=4.0, est=3.8754555527055143, details={'was_impossible': False}),
#  Prediction(uid='889', iid='747', r_ui=4.0, est=3.406248173031798, details={'was_impossible': False}),
#  Prediction(uid='189', iid='91', r_ui=3.0, est=4.222287757299771, details={'was_impossible': False}),
#  Prediction(uid='479', iid='270', r_ui=4.0, est=3.5794569421813978, details={'was_impossible': False}),
#  Prediction(uid='900', iid='136', r_ui=2.0, est=3.137447937255576, details={'was_impossible': False}),
#  Prediction(uid='24', iid='486', r_ui=3.0, est=4.244038534672259, details={'was_impossible': False}),
#  Prediction(uid='181', iid='978', r_ui=1.0, est=1, details={'was_impossible': False}),
#  Prediction(uid='72', iid='82', r_ui=3.0, est=3.595579035611917, details={'was_impossible': False}),
#  Prediction(uid='854', iid='421', r_ui=3.0, est=3.269112509202592, details={'was_impossible': False}),
#  Prediction(uid='860', iid='100', r_ui=4.0, est=3.8503431393952607, details={'was_impossible': False}),
#  Prediction(uid='537', iid='25', r_ui=2.0, est=2.5737598760361133, details={'was_impossible': False}),
#  Prediction(uid='659', iid='210', r_ui=5.0, est=4.023157620156357, details={'was_impossible': False}),
#  Prediction(uid='835', iid='673', r_ui=4.0, est=3.8998446322019693, details={'was_impossible': False}),
#  Prediction(uid='764', iid='64', r_ui=5.0, est=4.777161919259027, details={'was_impossible': False}),
#  Prediction(uid='222', iid='29', r_ui=3.0, est=2.6156597026743027, details={'was_impossible': False}),
#  Prediction(uid='402', iid='245', r_ui=1.0, est=3.2730651659882866, details={'was_impossible': False}),
#  Prediction(uid='690', iid='364', r_ui=3.0, est=2.4879241421733136, details={'was_impossible': False}),
#  Prediction(uid='407', iid='1044', r_ui=3.0, est=3.2202648191602288, details={'was_impossible': False}),
#  Prediction(uid='420', iid='86', r_ui=5.0, est=4.312361485707819, details={'was_impossible': False}),
#  Prediction(uid='553', iid='490', r_ui=4.0, est=4.408963743681601, details={'was_impossible': False}),
#  Prediction(uid='63', iid='6', r_ui=3.0, est=3.5075250028333285, details={'was_impossible': False}),
#  Prediction(uid='707', iid='736', r_ui=4.0, est=3.730628721891799, details={'was_impossible': False}),
#  Prediction(uid='345', iid='566', r_ui=3.0, est=3.3680322777578224, details={'was_impossible': False}),
#  Prediction(uid='601', iid='763', r_ui=5.0, est=2.811909984719247, details={'was_impossible': False}),
#  Prediction(uid='541', iid='465', r_ui=4.0, est=3.754186793745903, details={'was_impossible': False}),
#  Prediction(uid='363', iid='423', r_ui=3.0, est=2.834030077740777, details={'was_impossible': False}),
#  Prediction(uid='664', iid='56', r_ui=4.0, est=3.9485657297810928, details={'was_impossible': False}),
#  Prediction(uid='49', iid='173', r_ui=3.0, est=3.0635449245574606, details={'was_impossible': False}),
#  Prediction(uid='799', iid='289', r_ui=3.0, est=3.7888135743410127, details={'was_impossible': False}),
#  Prediction(uid='773', iid='1', r_ui=3.0, est=3.4136472535977265, details={'was_impossible': False}),
#  Prediction(uid='763', iid='162', r_ui=4.0, est=3.803479758328488, details={'was_impossible': False}),
#  Prediction(uid='303', iid='844', r_ui=3.0, est=3.633921503081632, details={'was_impossible': False}),
#  Prediction(uid='751', iid='433', r_ui=3.0, est=3.587464855203734, details={'was_impossible': False}),
#  Prediction(uid='92', iid='452', r_ui=2.0, est=2.584078398461069, details={'was_impossible': False}),
#  Prediction(uid='617', iid='7', r_ui=3.0, est=2.9454677665038465, details={'was_impossible': False}),
#  Prediction(uid='880', iid='316', r_ui=5.0, est=4.413074368719915, details={'was_impossible': False}),
#  Prediction(uid='25', iid='151', r_ui=4.0, est=3.764330444909535, details={'was_impossible': False}),
#  Prediction(uid='92', iid='25', r_ui=3.0, est=3.270959495520875, details={'was_impossible': False}),
#  Prediction(uid='18', iid='196', r_ui=3.0, est=3.8408501563643673, details={'was_impossible': False}),
#  Prediction(uid='271', iid='526', r_ui=5.0, est=4.270518626076979, details={'was_impossible': False}),
#  Prediction(uid='798', iid='1049', r_ui=3.0, est=2.5007020505453332, details={'was_impossible': False}),
#  Prediction(uid='697', iid='252', r_ui=1.0, est=3.5774514875048227, details={'was_impossible': False}),
#  Prediction(uid='676', iid='265', r_ui=5.0, est=4.042969091144553, details={'was_impossible': False}),
#  Prediction(uid='250', iid='135', r_ui=5.0, est=4.551998807174803, details={'was_impossible': False}),
#  Prediction(uid='6', iid='521', r_ui=4.0, est=3.4990912530572067, details={'was_impossible': False}),
#  Prediction(uid='664', iid='4', r_ui=4.0, est=3.489702926356597, details={'was_impossible': False}),
#  Prediction(uid='437', iid='221', r_ui=5.0, est=3.9787562675647488, details={'was_impossible': False}),
#  Prediction(uid='378', iid='569', r_ui=3.0, est=2.804811880522537, details={'was_impossible': False}),
#  Prediction(uid='447', iid='65', r_ui=3.0, est=3.3552229270258156, details={'was_impossible': False}),
#  Prediction(uid='11', iid='312', r_ui=4.0, est=3.0628335095727515, details={'was_impossible': False}),
#  Prediction(uid='395', iid='163', r_ui=5.0, est=3.678468481627143, details={'was_impossible': False}),
#  Prediction(uid='154', iid='191', r_ui=4.0, est=4.272827470931332, details={'was_impossible': False}),
#  Prediction(uid='881', iid='625', r_ui=5.0, est=2.838086468677102, details={'was_impossible': False}),
#  Prediction(uid='393', iid='1047', r_ui=3.0, est=2.843988288083708, details={'was_impossible': False}),
#  Prediction(uid='38', iid='402', r_ui=5.0, est=4.184451209075427, details={'was_impossible': False}),
#  Prediction(uid='22', iid='184', r_ui=5.0, est=3.5382082353633937, details={'was_impossible': False}),
#  Prediction(uid='326', iid='82', r_ui=3.0, est=3.197677046377401, details={'was_impossible': False}),
#  Prediction(uid='224', iid='662', r_ui=5.0, est=2.917896789098029, details={'was_impossible': False}),
#  Prediction(uid='43', iid='742', r_ui=5.0, est=4.2332864887735315, details={'was_impossible': False}),
#  Prediction(uid='186', iid='95', r_ui=3.0, est=4.170948742085271, details={'was_impossible': False}),
#  Prediction(uid='533', iid='103', r_ui=3.0, est=2.432463705041773, details={'was_impossible': False}),
#  Prediction(uid='316', iid='58', r_ui=3.0, est=3.029229333709742, details={'was_impossible': False}),
#  Prediction(uid='712', iid='210', r_ui=5.0, est=4.435749108615789, details={'was_impossible': False}),
#  Prediction(uid='840', iid='97', r_ui=3.0, est=3.9913587582384715, details={'was_impossible': False}),
#  Prediction(uid='293', iid='134', r_ui=5.0, est=3.969871901976965, details={'was_impossible': False}),
#  Prediction(uid='45', iid='952', r_ui=4.0, est=3.9297797444611904, details={'was_impossible': False}),
#  Prediction(uid='537', iid='517', r_ui=4.0, est=2.8028463394060683, details={'was_impossible': False}),
#  Prediction(uid='830', iid='925', r_ui=4.0, est=3.3650312488814667, details={'was_impossible': False}),
#  Prediction(uid='339', iid='525', r_ui=5.0, est=4.837396155409172, details={'was_impossible': False}),
#  Prediction(uid='492', iid='221', r_ui=3.0, est=3.456717966860648, details={'was_impossible': False}),
#  Prediction(uid='653', iid='386', r_ui=1.0, est=1.9239910400095677, details={'was_impossible': False}),
#  Prediction(uid='59', iid='1108', r_ui=3.0, est=3.5430779176203564, details={'was_impossible': False}),
#  Prediction(uid='198', iid='108', r_ui=3.0, est=2.763243262451881, details={'was_impossible': False}),
#  Prediction(uid='7', iid='198', r_ui=3.0, est=4.634809925317627, details={'was_impossible': False}),
#  Prediction(uid='90', iid='654', r_ui=5.0, est=4.656543151586085, details={'was_impossible': False}),
#  Prediction(uid='863', iid='752', r_ui=4.0, est=3.061167223406215, details={'was_impossible': False}),
#  Prediction(uid='716', iid='4', r_ui=2.0, est=3.4368474295625324, details={'was_impossible': False}),
#  Prediction(uid='871', iid='161', r_ui=5.0, est=3.2940198371810525, details={'was_impossible': False}),
#  Prediction(uid='894', iid='45', r_ui=4.0, est=4.21578373408229, details={'was_impossible': False}),
#  Prediction(uid='759', iid='118', r_ui=5.0, est=3.7338569059358147, details={'was_impossible': False}),
#  Prediction(uid='198', iid='1094', r_ui=1.0, est=2.733753166180133, details={'was_impossible': False}),
#  Prediction(uid='159', iid='872', r_ui=1.0, est=3.6313494226188947, details={'was_impossible': False}),
#  Prediction(uid='271', iid='275', r_ui=4.0, est=3.9346554668146054, details={'was_impossible': False}),
#  Prediction(uid='495', iid='62', r_ui=3.0, est=3.919624259081907, details={'was_impossible': False}),
#  Prediction(uid='276', iid='405', r_ui=3.0, est=3.3911787073504676, details={'was_impossible': False}),
#  Prediction(uid='450', iid='470', r_ui=5.0, est=3.953942985505489, details={'was_impossible': False}),
#  Prediction(uid='425', iid='679', r_ui=3.0, est=2.7006894484955506, details={'was_impossible': False}),
#  Prediction(uid='263', iid='322', r_ui=3.0, est=3.390088772745278, details={'was_impossible': False}),
#  Prediction(uid='313', iid='1066', r_ui=2.0, est=3.3944596938099374, details={'was_impossible': False}),
#  Prediction(uid='486', iid='129', r_ui=4.0, est=3.4576479150480246, details={'was_impossible': False}),
#  Prediction(uid='763', iid='237', r_ui=3.0, est=3.6895999193626072, details={'was_impossible': False}),
#  Prediction(uid='776', iid='53', r_ui=2.0, est=2.9022642983582942, details={'was_impossible': False}),
#  Prediction(uid='476', iid='585', r_ui=1.0, est=2.666754135846818, details={'was_impossible': False}),
#  Prediction(uid='913', iid='260', r_ui=1.0, est=2.4667641367526816, details={'was_impossible': False}),
#  Prediction(uid='198', iid='979', r_ui=5.0, est=2.809799842485723, details={'was_impossible': False}),
#  Prediction(uid='113', iid='127', r_ui=4.0, est=4.483442877188935, details={'was_impossible': False}),
#  Prediction(uid='551', iid='164', r_ui=4.0, est=4.391902863217058, details={'was_impossible': False}),
#  Prediction(uid='334', iid='498', r_ui=4.0, est=4.251294970174598, details={'was_impossible': False}),
#  Prediction(uid='526', iid='879', r_ui=3.0, est=2.8938529647430253, details={'was_impossible': False}),
#  Prediction(uid='540', iid='15', r_ui=3.0, est=4.0722874359083505, details={'was_impossible': False}),
#  Prediction(uid='246', iid='265', r_ui=4.0, est=2.9873184065624927, details={'was_impossible': False}),
#  Prediction(uid='537', iid='433', r_ui=4.0, est=2.899050290618985, details={'was_impossible': False}),
#  Prediction(uid='370', iid='265', r_ui=5.0, est=3.737079884966192, details={'was_impossible': False}),
#  Prediction(uid='178', iid='283', r_ui=5.0, est=3.600947972752366, details={'was_impossible': False}),
#  Prediction(uid='452', iid='419', r_ui=4.0, est=3.61149649273165, details={'was_impossible': False}),
#  Prediction(uid='566', iid='959', r_ui=4.0, est=3.3318591900397103, details={'was_impossible': False}),
#  Prediction(uid='698', iid='662', r_ui=2.0, est=2.502233250328044, details={'was_impossible': False}),
#  Prediction(uid='887', iid='84', r_ui=4.0, est=3.2350971487598628, details={'was_impossible': False}),
#  Prediction(uid='593', iid='471', r_ui=3.0, est=3.6686172077227037, details={'was_impossible': False}),
#  Prediction(uid='416', iid='204', r_ui=5.0, est=4.619907912318656, details={'was_impossible': False}),
#  Prediction(uid='354', iid='313', r_ui=3.0, est=4.246555095291526, details={'was_impossible': False}),
#  Prediction(uid='52', iid='250', r_ui=3.0, est=3.9706902799913406, details={'was_impossible': False}),
#  Prediction(uid='177', iid='179', r_ui=5.0, est=4.114522221021589, details={'was_impossible': False}),
#  Prediction(uid='870', iid='204', r_ui=4.0, est=3.1405468940554124, details={'was_impossible': False}),
#  Prediction(uid='64', iid='111', r_ui=4.0, est=3.457321838354809, details={'was_impossible': False}),
#  Prediction(uid='829', iid='10', r_ui=3.0, est=3.9111628326343815, details={'was_impossible': False}),
#  Prediction(uid='13', iid='200', r_ui=3.0, est=2.500868763303763, details={'was_impossible': False}),
#  Prediction(uid='222', iid='40', r_ui=1.0, est=2.458615717964153, details={'was_impossible': False}),
#  Prediction(uid='145', iid='212', r_ui=2.0, est=3.312580052815388, details={'was_impossible': False}),
#  Prediction(uid='449', iid='1372', r_ui=4.0, est=3.632849040478047, details={'was_impossible': False}),
#  Prediction(uid='760', iid='172', r_ui=3.0, est=3.7660220986212103, details={'was_impossible': False}),
#  Prediction(uid='358', iid='558', r_ui=4.0, est=3.7451022949162622, details={'was_impossible': False}),
#  Prediction(uid='807', iid='510', r_ui=5.0, est=4.1527112010772465, details={'was_impossible': False}),
#  Prediction(uid='752', iid='271', r_ui=5.0, est=3.594759299097351, details={'was_impossible': False}),
#  Prediction(uid='339', iid='250', r_ui=5.0, est=3.4938176494008872, details={'was_impossible': False}),
#  Prediction(uid='480', iid='654', r_ui=4.0, est=4.27077322639405, details={'was_impossible': False}),
#  Prediction(uid='605', iid='300', r_ui=2.0, est=3.3251522176703783, details={'was_impossible': False}),
#  Prediction(uid='95', iid='378', r_ui=4.0, est=3.868653971773359, details={'was_impossible': False}),
#  Prediction(uid='16', iid='423', r_ui=5.0, est=4.484914072489949, details={'was_impossible': False}),
#  Prediction(uid='826', iid='426', r_ui=2.0, est=3.5445813222738334, details={'was_impossible': False}),
#  Prediction(uid='405', iid='419', r_ui=4.0, est=2.881924598159613, details={'was_impossible': False}),
#  Prediction(uid='121', iid='180', r_ui=3.0, est=3.959035735734054, details={'was_impossible': False}),
#  Prediction(uid='751', iid='778', r_ui=3.0, est=3.5781594603651947, details={'was_impossible': False}),
#  Prediction(uid='442', iid='810', r_ui=2.0, est=2.485360972136537, details={'was_impossible': False}),
#  Prediction(uid='727', iid='95', r_ui=4.0, est=3.5981328534018915, details={'was_impossible': False}),
#  Prediction(uid='459', iid='258', r_ui=3.0, est=3.494834875002004, details={'was_impossible': False}),
#  Prediction(uid='416', iid='742', r_ui=4.0, est=3.6558932631368215, details={'was_impossible': False}),
#  Prediction(uid='539', iid='289', r_ui=4.0, est=3.1545492592826374, details={'was_impossible': False}),
#  Prediction(uid='429', iid='280', r_ui=2.0, est=3.0492606803954496, details={'was_impossible': False}),
#  Prediction(uid='151', iid='939', r_ui=4.0, est=3.7624304471458587, details={'was_impossible': False}),
#  Prediction(uid='880', iid='1620', r_ui=3.0, est=3.3632294634781057, details={'was_impossible': False}),
#  Prediction(uid='883', iid='372', r_ui=3.0, est=3.85929352481961, details={'was_impossible': False}),
#  Prediction(uid='6', iid='301', r_ui=2.0, est=2.637272837357741, details={'was_impossible': False}),
#  Prediction(uid='864', iid='523', r_ui=4.0, est=3.8105377478940943, details={'was_impossible': False}),
#  Prediction(uid='13', iid='887', r_ui=5.0, est=3.2288595424768656, details={'was_impossible': False}),
#  Prediction(uid='447', iid='762', r_ui=3.0, est=3.310867130167391, details={'was_impossible': False}),
#  Prediction(uid='19', iid='210', r_ui=3.0, est=4.096312817825357, details={'was_impossible': False}),
#  Prediction(uid='504', iid='693', r_ui=4.0, est=3.971532787354466, details={'was_impossible': False}),
#  Prediction(uid='897', iid='205', r_ui=3.0, est=4.244621333259293, details={'was_impossible': False}),
#  Prediction(uid='330', iid='51', r_ui=5.0, est=4.531775324774165, details={'was_impossible': False}),
#  Prediction(uid='695', iid='678', r_ui=4.0, est=2.5229374634529593, details={'was_impossible': False}),
#  Prediction(uid='506', iid='482', r_ui=5.0, est=4.007680521886489, details={'was_impossible': False}),
#  Prediction(uid='897', iid='433', r_ui=4.0, est=3.5858796390834478, details={'was_impossible': False}),
#  Prediction(uid='7', iid='269', r_ui=3.0, est=4.293877797280398, details={'was_impossible': False}),
#  Prediction(uid='533', iid='215', r_ui=4.0, est=3.793596947736108, details={'was_impossible': False}),
#  Prediction(uid='451', iid='319', r_ui=2.0, est=2.855773415084072, details={'was_impossible': False}),
#  Prediction(uid='83', iid='591', r_ui=4.0, est=3.8328838217949683, details={'was_impossible': False}),
#  Prediction(uid='885', iid='95', r_ui=4.0, est=3.561000365667737, details={'was_impossible': False}),
#  Prediction(uid='851', iid='328', r_ui=3.0, est=3.3186833202655515, details={'was_impossible': False}),
#  Prediction(uid='262', iid='781', r_ui=3.0, est=3.158818800824955, details={'was_impossible': False}),
#  Prediction(uid='301', iid='514', r_ui=3.0, est=3.9379091134906883, details={'was_impossible': False}),
#  Prediction(uid='625', iid='197', r_ui=5.0, est=3.5428887998404717, details={'was_impossible': False}),
#  Prediction(uid='357', iid='126', r_ui=5.0, est=4.490576993212131, details={'was_impossible': False}),
#  Prediction(uid='351', iid='245', r_ui=3.0, est=3.9856509217885088, details={'was_impossible': False}),
#  Prediction(uid='846', iid='693', r_ui=5.0, est=4.069182491975165, details={'was_impossible': False}),
#  Prediction(uid='235', iid='213', r_ui=4.0, est=4.271013231005679, details={'was_impossible': False}),
#  Prediction(uid='417', iid='101', r_ui=3.0, est=3.1543813071538582, details={'was_impossible': False}),
#  Prediction(uid='892', iid='484', r_ui=5.0, est=4.587526528175707, details={'was_impossible': False}),
#  Prediction(uid='515', iid='1430', r_ui=3.0, est=3.16630267212886, details={'was_impossible': False}),
#  Prediction(uid='159', iid='1025', r_ui=2.0, est=3.511622114671098, details={'was_impossible': False}),
#  Prediction(uid='823', iid='111', r_ui=4.0, est=4.01609450458481, details={'was_impossible': False}),
#  Prediction(uid='85', iid='657', r_ui=4.0, est=4.082411175234713, details={'was_impossible': False}),
#  Prediction(uid='152', iid='660', r_ui=5.0, est=4.81830240457205, details={'was_impossible': False}),
#  Prediction(uid='321', iid='480', r_ui=4.0, est=4.231028754821552, details={'was_impossible': False}),
#  Prediction(uid='452', iid='492', r_ui=4.0, est=3.656616768244601, details={'was_impossible': False}),
#  Prediction(uid='468', iid='42', r_ui=4.0, est=3.972370877305443, details={'was_impossible': False}),
#  Prediction(uid='528', iid='748', r_ui=3.0, est=3.5676427234370673, details={'was_impossible': False}),
#  Prediction(uid='492', iid='137', r_ui=4.0, est=3.4260658885677286, details={'was_impossible': False}),
#  Prediction(uid='271', iid='747', r_ui=3.0, est=3.3653681333735297, details={'was_impossible': False}),
#  Prediction(uid='405', iid='726', r_ui=1.0, est=1.2052219743222055, details={'was_impossible': False}),
#  Prediction(uid='303', iid='42', r_ui=5.0, est=4.088491433559778, details={'was_impossible': False}),
#  Prediction(uid='827', iid='343', r_ui=4.0, est=2.8139541936470938, details={'was_impossible': False}),
#  Prediction(uid='532', iid='51', r_ui=5.0, est=4.442098468490015, details={'was_impossible': False}),
#  Prediction(uid='932', iid='357', r_ui=5.0, est=4.407827423750994, details={'was_impossible': False}),
#  Prediction(uid='373', iid='286', r_ui=3.0, est=3.6506341151569504, details={'was_impossible': False}),
#  Prediction(uid='291', iid='1016', r_ui=4.0, est=3.5987608350319364, details={'was_impossible': False}),
#  Prediction(uid='544', iid='312', r_ui=2.0, est=2.74425271982952, details={'was_impossible': False}),
#  Prediction(uid='18', iid='238', r_ui=5.0, est=4.09542608534948, details={'was_impossible': False}),
#  Prediction(uid='82', iid='1063', r_ui=3.0, est=2.828794831362005, details={'was_impossible': False}),
#  Prediction(uid='889', iid='169', r_ui=5.0, est=4.358066825759783, details={'was_impossible': False}),
#  Prediction(uid='409', iid='270', r_ui=2.0, est=3.376123632259541, details={'was_impossible': False}),
#  Prediction(uid='889', iid='1142', r_ui=4.0, est=3.603467774609113, details={'was_impossible': False}),
#  Prediction(uid='39', iid='748', r_ui=5.0, est=2.9857502486597958, details={'was_impossible': False}),
#  Prediction(uid='59', iid='229', r_ui=3.0, est=3.4771331285917495, details={'was_impossible': False}),
#  Prediction(uid='397', iid='23', r_ui=5.0, est=3.828922283529804, details={'was_impossible': False}),
#  Prediction(uid='327', iid='811', r_ui=4.0, est=3.6882026118143107, details={'was_impossible': False}),
#  Prediction(uid='528', iid='1618', r_ui=1.0, est=3.454027275400416, details={'was_impossible': False}),
#  Prediction(uid='320', iid='763', r_ui=4.0, est=4.086402827911777, details={'was_impossible': False}),
#  Prediction(uid='890', iid='200', r_ui=4.0, est=4.168921172499891, details={'was_impossible': False}),
#  Prediction(uid='325', iid='345', r_ui=3.0, est=3.322065258177632, details={'was_impossible': False}),
#  Prediction(uid='622', iid='373', r_ui=1.0, est=2.8292567298832827, details={'was_impossible': False}),
#  Prediction(uid='883', iid='749', r_ui=3.0, est=2.99244929522896, details={'was_impossible': False}),
#  Prediction(uid='938', iid='685', r_ui=3.0, est=3.130059391942129, details={'was_impossible': False}),
#  Prediction(uid='545', iid='230', r_ui=5.0, est=3.644166270795765, details={'was_impossible': False}),
#  Prediction(uid='487', iid='578', r_ui=3.0, est=3.1483641923704475, details={'was_impossible': False}),
#  Prediction(uid='716', iid='792', r_ui=4.0, est=3.856756593192341, details={'was_impossible': False}),
#  Prediction(uid='416', iid='143', r_ui=5.0, est=4.574967477207327, details={'was_impossible': False}),
#  Prediction(uid='74', iid='539', r_ui=3.0, est=2.671636662245927, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1296', r_ui=1.0, est=1.8056233201731198, details={'was_impossible': False}),
#  Prediction(uid='453', iid='11', r_ui=5.0, est=3.6644044241538274, details={'was_impossible': False}),
#  Prediction(uid='882', iid='177', r_ui=5.0, est=3.980792044315873, details={'was_impossible': False}),
#  Prediction(uid='452', iid='83', r_ui=3.0, est=3.747468273565072, details={'was_impossible': False}),
#  Prediction(uid='790', iid='949', r_ui=4.0, est=3.065217515184562, details={'was_impossible': False}),
#  Prediction(uid='753', iid='510', r_ui=4.0, est=3.5201168228915907, details={'was_impossible': False}),
#  Prediction(uid='59', iid='523', r_ui=4.0, est=4.026261679161664, details={'was_impossible': False}),
#  Prediction(uid='151', iid='100', r_ui=3.0, est=4.4285882299161, details={'was_impossible': False}),
#  Prediction(uid='374', iid='164', r_ui=4.0, est=4.337167008499518, details={'was_impossible': False}),
#  Prediction(uid='711', iid='316', r_ui=4.0, est=4.379930973698361, details={'was_impossible': False}),
#  Prediction(uid='328', iid='50', r_ui=4.0, est=3.791945112066251, details={'was_impossible': False}),
#  Prediction(uid='6', iid='50', r_ui=4.0, est=4.195219299421213, details={'was_impossible': False}),
#  Prediction(uid='318', iid='768', r_ui=2.0, est=3.1491464557436477, details={'was_impossible': False}),
#  Prediction(uid='201', iid='32', r_ui=3.0, est=3.6590261243084443, details={'was_impossible': False}),
#  Prediction(uid='457', iid='143', r_ui=5.0, est=3.9879299640909434, details={'was_impossible': False}),
#  Prediction(uid='156', iid='157', r_ui=4.0, est=3.2034401836285804, details={'was_impossible': False}),
#  Prediction(uid='25', iid='612', r_ui=4.0, est=3.983612616047986, details={'was_impossible': False}),
#  Prediction(uid='798', iid='560', r_ui=3.0, est=2.926000150250038, details={'was_impossible': False}),
#  Prediction(uid='637', iid='111', r_ui=3.0, est=2.687290499234773, details={'was_impossible': False}),
#  Prediction(uid='708', iid='1117', r_ui=4.0, est=3.0494157968224727, details={'was_impossible': False}),
#  Prediction(uid='59', iid='729', r_ui=4.0, est=3.9367882024658987, details={'was_impossible': False}),
#  Prediction(uid='83', iid='248', r_ui=3.0, est=3.6453437340566763, details={'was_impossible': False}),
#  Prediction(uid='148', iid='474', r_ui=5.0, est=4.0384086345077765, details={'was_impossible': False}),
#  Prediction(uid='854', iid='83', r_ui=4.0, est=3.6828182581396387, details={'was_impossible': False}),
#  Prediction(uid='393', iid='871', r_ui=3.0, est=2.660861204118567, details={'was_impossible': False}),
#  Prediction(uid='52', iid='235', r_ui=2.0, est=3.3790898070091218, details={'was_impossible': False}),
#  Prediction(uid='229', iid='260', r_ui=1.0, est=2.2591305827713732, details={'was_impossible': False}),
#  Prediction(uid='149', iid='272', r_ui=3.0, est=3.647191251167732, details={'was_impossible': False}),
#  Prediction(uid='488', iid='294', r_ui=4.0, est=2.960781958864492, details={'was_impossible': False}),
#  Prediction(uid='14', iid='175', r_ui=5.0, est=4.279608442304699, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1228', r_ui=1.0, est=1, details={'was_impossible': False}),
#  Prediction(uid='615', iid='302', r_ui=4.0, est=4.3530436356622, details={'was_impossible': False}),
#  Prediction(uid='650', iid='206', r_ui=4.0, est=3.163114329669674, details={'was_impossible': False}),
#  Prediction(uid='213', iid='463', r_ui=5.0, est=4.4064596385795864, details={'was_impossible': False}),
#  Prediction(uid='379', iid='447', r_ui=4.0, est=3.9535896270121915, details={'was_impossible': False}),
#  Prediction(uid='313', iid='187', r_ui=4.0, est=4.062224033635585, details={'was_impossible': False}),
#  Prediction(uid='77', iid='175', r_ui=4.0, est=3.457819059103943, details={'was_impossible': False}),
#  Prediction(uid='577', iid='808', r_ui=3.0, est=3.342619800917973, details={'was_impossible': False}),
#  Prediction(uid='62', iid='171', r_ui=4.0, est=3.614862681518053, details={'was_impossible': False}),
#  Prediction(uid='589', iid='333', r_ui=5.0, est=3.3376586088263367, details={'was_impossible': False}),
#  Prediction(uid='588', iid='402', r_ui=5.0, est=3.615084766152743, details={'was_impossible': False}),
#  Prediction(uid='254', iid='199', r_ui=4.0, est=3.9922925100272657, details={'was_impossible': False}),
#  Prediction(uid='268', iid='208', r_ui=4.0, est=3.6595403200735355, details={'was_impossible': False}),
#  Prediction(uid='303', iid='402', r_ui=4.0, est=3.0093965003887315, details={'was_impossible': False}),
#  Prediction(uid='259', iid='98', r_ui=4.0, est=4.418637701305641, details={'was_impossible': False}),
#  Prediction(uid='50', iid='286', r_ui=2.0, est=4.1827549447252315, details={'was_impossible': False}),
#  Prediction(uid='85', iid='631', r_ui=4.0, est=3.2372633861097357, details={'was_impossible': False}),
#  Prediction(uid='460', iid='129', r_ui=3.0, est=3.5375956838864893, details={'was_impossible': False}),
#  Prediction(uid='875', iid='195', r_ui=4.0, est=4.243777802520761, details={'was_impossible': False}),
#  Prediction(uid='404', iid='342', r_ui=3.0, est=2.5808233072340885, details={'was_impossible': False}),
#  Prediction(uid='439', iid='285', r_ui=5.0, est=4.45452808322686, details={'was_impossible': False}),
#  Prediction(uid='174', iid='949', r_ui=5.0, est=3.615070085909801, details={'was_impossible': False}),
#  Prediction(uid='829', iid='339', r_ui=2.0, est=2.850999680297722, details={'was_impossible': False}),
#  Prediction(uid='405', iid='606', r_ui=3.0, est=2.641259906613075, details={'was_impossible': False}),
#  Prediction(uid='32', iid='250', r_ui=4.0, est=3.499278891386593, details={'was_impossible': False}),
#  Prediction(uid='70', iid='527', r_ui=4.0, est=3.993445835301131, details={'was_impossible': False}),
#  Prediction(uid='344', iid='315', r_ui=5.0, est=4.163312084525052, details={'was_impossible': False}),
#  Prediction(uid='450', iid='94', r_ui=4.0, est=3.602335089091544, details={'was_impossible': False}),
#  Prediction(uid='694', iid='657', r_ui=4.0, est=4.573978006682376, details={'was_impossible': False}),
#  Prediction(uid='833', iid='262', r_ui=2.0, est=3.6397130085662974, details={'was_impossible': False}),
#  Prediction(uid='254', iid='1091', r_ui=3.0, est=2.4613339731790957, details={'was_impossible': False}),
#  Prediction(uid='707', iid='1174', r_ui=5.0, est=2.985267266570672, details={'was_impossible': False}),
#  Prediction(uid='38', iid='1028', r_ui=5.0, est=3.7102234271003454, details={'was_impossible': False}),
#  Prediction(uid='145', iid='1087', r_ui=1.0, est=3.014452685887687, details={'was_impossible': False}),
#  Prediction(uid='271', iid='528', r_ui=3.0, est=3.9343134671866533, details={'was_impossible': False}),
#  Prediction(uid='712', iid='69', r_ui=3.0, est=4.580868827085417, details={'was_impossible': False}),
#  Prediction(uid='903', iid='288', r_ui=4.0, est=3.457673164113234, details={'was_impossible': False}),
#  Prediction(uid='398', iid='172', r_ui=5.0, est=4.271368890764072, details={'was_impossible': False}),
#  Prediction(uid='305', iid='469', r_ui=2.0, est=3.597984882868415, details={'was_impossible': False}),
#  Prediction(uid='618', iid='233', r_ui=3.0, est=2.9904110904216252, details={'was_impossible': False}),
#  Prediction(uid='780', iid='286', r_ui=4.0, est=3.4083169852865214, details={'was_impossible': False}),
#  Prediction(uid='650', iid='29', r_ui=2.0, est=2.398632187632857, details={'was_impossible': False}),
#  Prediction(uid='430', iid='181', r_ui=4.0, est=3.803798921795951, details={'was_impossible': False}),
#  Prediction(uid='486', iid='127', r_ui=5.0, est=4.202250841343378, details={'was_impossible': False}),
#  Prediction(uid='776', iid='656', r_ui=5.0, est=3.6404709862862994, details={'was_impossible': False}),
# ...
#  Prediction(uid='10', iid='85', r_ui=4.0, est=3.291718654883611, details={'was_impossible': False}),
#  Prediction(uid='690', iid='780', r_ui=4.0, est=2.8670624263508095, details={'was_impossible': False}),
#  Prediction(uid='141', iid='125', r_ui=5.0, est=3.467518405119865, details={'was_impossible': False}),
#  Prediction(uid='669', iid='23', r_ui=4.0, est=3.89454787903452, details={'was_impossible': False}),
#  Prediction(uid='116', iid='286', r_ui=3.0, est=2.6992330635635824, details={'was_impossible': False}),
#  Prediction(uid='451', iid='335', r_ui=4.0, est=2.5400810266998857, details={'was_impossible': False}),
#  Prediction(uid='1', iid='167', r_ui=2.0, est=2.9770052466753927, details={'was_impossible': False}),
#  Prediction(uid='94', iid='28', r_ui=4.0, est=3.742431368401183, details={'was_impossible': False}),
#  Prediction(uid='320', iid='89', r_ui=4.0, est=4.581016611587744, details={'was_impossible': False}),
#  Prediction(uid='774', iid='527', r_ui=1.0, est=2.925194362827532, details={'was_impossible': False}),
#  Prediction(uid='927', iid='542', r_ui=2.0, est=3.2535066704869933, details={'was_impossible': False}),
#  Prediction(uid='654', iid='4', r_ui=4.0, est=3.7881302778446004, details={'was_impossible': False}),
#  Prediction(uid='519', iid='259', r_ui=1.0, est=3.74993900056408, details={'was_impossible': False}),
#  Prediction(uid='44', iid='378', r_ui=3.0, est=3.982910029655939, details={'was_impossible': False}),
#  Prediction(uid='293', iid='420', r_ui=4.0, est=3.118797356055807, details={'was_impossible': False}),
#  Prediction(uid='364', iid='948', r_ui=4.0, est=2.607683181200164, details={'was_impossible': False}),
#  Prediction(uid='630', iid='820', r_ui=4.0, est=2.8593161361928603, details={'was_impossible': False}),
#  Prediction(uid='343', iid='86', r_ui=5.0, est=4.185643726148137, details={'was_impossible': False}),
#  Prediction(uid='63', iid='109', r_ui=4.0, est=2.9272077354267148, details={'was_impossible': False}),
#  Prediction(uid='863', iid='319', r_ui=2.0, est=3.210440751958637, details={'was_impossible': False}),
#  Prediction(uid='489', iid='678', r_ui=4.0, est=3.6433772806445357, details={'was_impossible': False}),
#  Prediction(uid='321', iid='182', r_ui=3.0, est=3.836275525989035, details={'was_impossible': False}),
#  Prediction(uid='130', iid='291', r_ui=4.0, est=4.2641374597151085, details={'was_impossible': False}),
#  Prediction(uid='164', iid='333', r_ui=5.0, est=4.446600803323626, details={'was_impossible': False}),
#  Prediction(uid='790', iid='1446', r_ui=4.0, est=3.1691861015187963, details={'was_impossible': False}),
#  Prediction(uid='880', iid='1139', r_ui=4.0, est=2.765566972521452, details={'was_impossible': False}),
#  Prediction(uid='411', iid='1470', r_ui=3.0, est=2.8837107771388073, details={'was_impossible': False}),
#  Prediction(uid='620', iid='1503', r_ui=4.0, est=3.820121053908404, details={'was_impossible': False}),
#  Prediction(uid='299', iid='483', r_ui=5.0, est=3.992746321240948, details={'was_impossible': False}),
#  Prediction(uid='311', iid='1297', r_ui=4.0, est=3.2328338469527256, details={'was_impossible': False}),
#  Prediction(uid='23', iid='195', r_ui=4.0, est=3.396107593657157, details={'was_impossible': False}),
#  Prediction(uid='795', iid='202', r_ui=3.0, est=3.047684601558805, details={'was_impossible': False}),
#  Prediction(uid='148', iid='227', r_ui=4.0, est=3.4680773216446417, details={'was_impossible': False}),
#  Prediction(uid='199', iid='313', r_ui=4.0, est=3.940542906601944, details={'was_impossible': False}),
#  Prediction(uid='267', iid='174', r_ui=5.0, est=4.789042210470534, details={'was_impossible': False}),
#  Prediction(uid='384', iid='748', r_ui=4.0, est=3.550710812657332, details={'was_impossible': False}),
#  Prediction(uid='276', iid='373', r_ui=2.0, est=2.913582027524144, details={'was_impossible': False}),
#  Prediction(uid='640', iid='12', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='796', iid='849', r_ui=4.0, est=2.8773671070117115, details={'was_impossible': False}),
#  Prediction(uid='172', iid='428', r_ui=4.0, est=3.315748570829677, details={'was_impossible': False}),
#  Prediction(uid='429', iid='32', r_ui=4.0, est=3.7441497559540986, details={'was_impossible': False}),
#  Prediction(uid='943', iid='576', r_ui=4.0, est=2.7376762788051248, details={'was_impossible': False}),
#  Prediction(uid='637', iid='255', r_ui=3.0, est=2.574366321508363, details={'was_impossible': False}),
#  Prediction(uid='254', iid='230', r_ui=4.0, est=3.6678551787538947, details={'was_impossible': False}),
#  Prediction(uid='881', iid='63', r_ui=4.0, est=2.949851793804559, details={'was_impossible': False}),
#  Prediction(uid='894', iid='1462', r_ui=3.0, est=3.6415636938773095, details={'was_impossible': False}),
#  Prediction(uid='374', iid='38', r_ui=4.0, est=2.6331938531057, details={'was_impossible': False}),
#  Prediction(uid='244', iid='241', r_ui=4.0, est=3.2279384743264594, details={'was_impossible': False}),
#  Prediction(uid='325', iid='443', r_ui=4.0, est=3.6593837173392503, details={'was_impossible': False}),
#  Prediction(uid='183', iid='720', r_ui=4.0, est=2.779467929656675, details={'was_impossible': False}),
#  Prediction(uid='178', iid='156', r_ui=2.0, est=3.7470873011326975, details={'was_impossible': False}),
#  Prediction(uid='821', iid='148', r_ui=3.0, est=4.021868751464267, details={'was_impossible': False}),
#  Prediction(uid='746', iid='82', r_ui=4.0, est=3.4800188174136424, details={'was_impossible': False}),
#  Prediction(uid='455', iid='447', r_ui=4.0, est=3.5606672830242134, details={'was_impossible': False}),
#  Prediction(uid='45', iid='111', r_ui=4.0, est=3.8727143443185845, details={'was_impossible': False}),
#  Prediction(uid='742', iid='222', r_ui=2.0, est=3.7949625380302776, details={'was_impossible': False}),
#  Prediction(uid='618', iid='462', r_ui=2.0, est=3.503502032823449, details={'was_impossible': False}),
#  Prediction(uid='10', iid='474', r_ui=4.0, est=4.674729339184889, details={'was_impossible': False}),
#  Prediction(uid='838', iid='455', r_ui=4.0, est=3.6337005328988927, details={'was_impossible': False}),
#  Prediction(uid='350', iid='168', r_ui=5.0, est=4.368452257336887, details={'was_impossible': False}),
#  Prediction(uid='145', iid='591', r_ui=4.0, est=3.6115933054355294, details={'was_impossible': False}),
#  Prediction(uid='459', iid='932', r_ui=4.0, est=3.1884936431989, details={'was_impossible': False}),
#  Prediction(uid='637', iid='293', r_ui=3.0, est=3.1685305552807805, details={'was_impossible': False}),
#  Prediction(uid='504', iid='756', r_ui=3.0, est=3.442736011837372, details={'was_impossible': False}),
#  Prediction(uid='514', iid='68', r_ui=4.0, est=3.667293062916166, details={'was_impossible': False}),
#  Prediction(uid='907', iid='1040', r_ui=5.0, est=3.646822390422404, details={'was_impossible': False}),
#  Prediction(uid='694', iid='603', r_ui=4.0, est=4.714248623337761, details={'was_impossible': False}),
#  Prediction(uid='737', iid='22', r_ui=4.0, est=3.9077266571522, details={'was_impossible': False}),
#  Prediction(uid='90', iid='518', r_ui=2.0, est=4.024066998468212, details={'was_impossible': False}),
#  Prediction(uid='327', iid='336', r_ui=2.0, est=1.9643478188953667, details={'was_impossible': False}),
#  Prediction(uid='527', iid='543', r_ui=4.0, est=3.3171240703296814, details={'was_impossible': False}),
#  Prediction(uid='249', iid='634', r_ui=5.0, est=4.215955773269781, details={'was_impossible': False}),
#  Prediction(uid='269', iid='3', r_ui=3.0, est=2.263856695700472, details={'was_impossible': False}),
#  Prediction(uid='426', iid='631', r_ui=3.0, est=3.6262002900310333, details={'was_impossible': False}),
#  Prediction(uid='295', iid='133', r_ui=4.0, est=4.379486058590662, details={'was_impossible': False}),
#  Prediction(uid='712', iid='692', r_ui=5.0, est=4.094258239254471, details={'was_impossible': False}),
#  Prediction(uid='828', iid='900', r_ui=2.0, est=3.551862245083161, details={'was_impossible': False}),
#  Prediction(uid='148', iid='969', r_ui=4.0, est=3.8855607164097767, details={'was_impossible': False}),
#  Prediction(uid='294', iid='260', r_ui=4.0, est=2.7734173922354612, details={'was_impossible': False}),
#  Prediction(uid='189', iid='216', r_ui=5.0, est=4.290931462833594, details={'was_impossible': False}),
#  Prediction(uid='508', iid='23', r_ui=4.0, est=4.020120636790018, details={'was_impossible': False}),
#  Prediction(uid='398', iid='498', r_ui=5.0, est=4.067028571317551, details={'was_impossible': False}),
#  Prediction(uid='363', iid='333', r_ui=1.0, est=3.4452522966354633, details={'was_impossible': False}),
#  Prediction(uid='406', iid='99', r_ui=5.0, est=3.616053233055963, details={'was_impossible': False}),
#  Prediction(uid='234', iid='423', r_ui=4.0, est=3.71159432677514, details={'was_impossible': False}),
#  Prediction(uid='294', iid='7', r_ui=4.0, est=4.335489499327004, details={'was_impossible': False}),
#  Prediction(uid='520', iid='893', r_ui=2.0, est=2.946701223820667, details={'was_impossible': False}),
#  Prediction(uid='480', iid='249', r_ui=1.0, est=3.6304005166650803, details={'was_impossible': False}),
#  Prediction(uid='748', iid='286', r_ui=3.0, est=3.0135647072565184, details={'was_impossible': False}),
#  Prediction(uid='15', iid='933', r_ui=1.0, est=2.65166176541865, details={'was_impossible': False}),
#  Prediction(uid='608', iid='92', r_ui=3.0, est=3.3534649082663823, details={'was_impossible': False}),
#  Prediction(uid='560', iid='1163', r_ui=3.0, est=2.7169781620100446, details={'was_impossible': False}),
#  Prediction(uid='650', iid='151', r_ui=3.0, est=3.3492706938002277, details={'was_impossible': False}),
#  Prediction(uid='123', iid='707', r_ui=5.0, est=3.704982075082839, details={'was_impossible': False}),
#  Prediction(uid='804', iid='514', r_ui=4.0, est=3.7091280695434836, details={'was_impossible': False}),
#  Prediction(uid='733', iid='1132', r_ui=4.0, est=2.3958932668661665, details={'was_impossible': False}),
#  Prediction(uid='311', iid='50', r_ui=5.0, est=4.448920590558033, details={'was_impossible': False}),
#  Prediction(uid='666', iid='805', r_ui=4.0, est=3.5898875158996777, details={'was_impossible': False}),
#  Prediction(uid='655', iid='297', r_ui=4.0, est=3.1440215621694634, details={'was_impossible': False}),
#  Prediction(uid='934', iid='708', r_ui=3.0, est=3.3891687663849215, details={'was_impossible': False}),
#  Prediction(uid='805', iid='248', r_ui=4.0, est=3.5098074056784396, details={'was_impossible': False}),
#  Prediction(uid='829', iid='124', r_ui=4.0, est=3.7327889124319373, details={'was_impossible': False}),
#  Prediction(uid='655', iid='1017', r_ui=3.0, est=2.7913522082504407, details={'was_impossible': False}),
#  Prediction(uid='554', iid='8', r_ui=4.0, est=3.633753117010992, details={'was_impossible': False}),
#  Prediction(uid='497', iid='144', r_ui=4.0, est=3.6284217598579502, details={'was_impossible': False}),
#  Prediction(uid='875', iid='504', r_ui=5.0, est=4.255018152439451, details={'was_impossible': False}),
#  Prediction(uid='693', iid='568', r_ui=4.0, est=2.9858435966471397, details={'was_impossible': False}),
#  Prediction(uid='533', iid='475', r_ui=1.0, est=2.570467014586381, details={'was_impossible': False}),
#  Prediction(uid='70', iid='678', r_ui=3.0, est=3.0820859318123786, details={'was_impossible': False}),
#  Prediction(uid='381', iid='634', r_ui=3.0, est=3.6986301713718306, details={'was_impossible': False}),
#  Prediction(uid='622', iid='395', r_ui=2.0, est=2.2194432052760327, details={'was_impossible': False}),
#  Prediction(uid='389', iid='663', r_ui=4.0, est=3.7239505366269317, details={'was_impossible': False}),
#  Prediction(uid='7', iid='125', r_ui=4.0, est=3.813058565544028, details={'was_impossible': False}),
#  Prediction(uid='189', iid='121', r_ui=2.0, est=3.302675289951167, details={'was_impossible': False}),
#  Prediction(uid='524', iid='978', r_ui=3.0, est=2.1930556542740067, details={'was_impossible': False}),
#  Prediction(uid='758', iid='722', r_ui=3.0, est=3.143666741853435, details={'was_impossible': False}),
#  Prediction(uid='175', iid='9', r_ui=4.0, est=3.814053754093708, details={'was_impossible': False}),
#  Prediction(uid='47', iid='874', r_ui=3.0, est=3.536684444020164, details={'was_impossible': False}),
#  Prediction(uid='551', iid='719', r_ui=1.0, est=2.8838488768955455, details={'was_impossible': False}),
#  Prediction(uid='563', iid='678', r_ui=2.0, est=3.307990797273465, details={'was_impossible': False}),
#  Prediction(uid='392', iid='180', r_ui=5.0, est=4.185219785436395, details={'was_impossible': False}),
#  Prediction(uid='613', iid='576', r_ui=3.0, est=3.4911152327205777, details={'was_impossible': False}),
#  Prediction(uid='393', iid='866', r_ui=3.0, est=3.6735664919735167, details={'was_impossible': False}),
#  Prediction(uid='130', iid='258', r_ui=4.0, est=4.7587014119196915, details={'was_impossible': False}),
#  Prediction(uid='57', iid='250', r_ui=3.0, est=3.606411534890924, details={'was_impossible': False}),
#  Prediction(uid='119', iid='86', r_ui=4.0, est=4.188400131493973, details={'was_impossible': False}),
#  Prediction(uid='479', iid='179', r_ui=1.0, est=3.7815698483647138, details={'was_impossible': False}),
#  Prediction(uid='401', iid='365', r_ui=4.0, est=3.007983192535158, details={'was_impossible': False}),
#  Prediction(uid='887', iid='839', r_ui=4.0, est=4.2009462281099035, details={'was_impossible': False}),
#  Prediction(uid='650', iid='174', r_ui=4.0, est=3.770994314690368, details={'was_impossible': False}),
#  Prediction(uid='896', iid='572', r_ui=2.0, est=2.0352168069682617, details={'was_impossible': False}),
#  Prediction(uid='18', iid='509', r_ui=4.0, est=4.242324910451302, details={'was_impossible': False}),
#  Prediction(uid='474', iid='203', r_ui=5.0, est=4.1837391557149335, details={'was_impossible': False}),
#  Prediction(uid='847', iid='183', r_ui=4.0, est=3.2733212360826704, details={'was_impossible': False}),
#  Prediction(uid='903', iid='25', r_ui=4.0, est=3.252020029568412, details={'was_impossible': False}),
#  Prediction(uid='773', iid='1036', r_ui=3.0, est=2.3320803756145616, details={'was_impossible': False}),
#  Prediction(uid='843', iid='194', r_ui=2.0, est=3.2929351232921613, details={'was_impossible': False}),
#  Prediction(uid='64', iid='62', r_ui=2.0, est=2.9526427949569993, details={'was_impossible': False}),
#  Prediction(uid='716', iid='627', r_ui=4.0, est=3.352784181420743, details={'was_impossible': False}),
#  Prediction(uid='321', iid='1101', r_ui=3.0, est=3.8075848672046857, details={'was_impossible': False}),
#  Prediction(uid='655', iid='1186', r_ui=3.0, est=2.846058552942668, details={'was_impossible': False}),
#  Prediction(uid='871', iid='1022', r_ui=3.0, est=3.126319877379392, details={'was_impossible': False}),
#  Prediction(uid='295', iid='451', r_ui=4.0, est=4.235115605603883, details={'was_impossible': False}),
#  Prediction(uid='94', iid='549', r_ui=5.0, est=3.587525701324523, details={'was_impossible': False}),
#  Prediction(uid='32', iid='249', r_ui=4.0, est=3.3835966207302373, details={'was_impossible': False}),
#  Prediction(uid='378', iid='238', r_ui=3.0, est=3.7792704059777615, details={'was_impossible': False}),
#  Prediction(uid='95', iid='560', r_ui=1.0, est=2.594016138650016, details={'was_impossible': False}),
#  Prediction(uid='881', iid='748', r_ui=3.0, est=2.928397781243822, details={'was_impossible': False}),
#  Prediction(uid='393', iid='365', r_ui=3.0, est=3.5054403908739555, details={'was_impossible': False}),
#  Prediction(uid='104', iid='100', r_ui=4.0, est=3.70265382702199, details={'was_impossible': False}),
#  Prediction(uid='435', iid='33', r_ui=3.0, est=3.402770864275332, details={'was_impossible': False}),
#  Prediction(uid='551', iid='660', r_ui=3.0, est=4.636419989135249, details={'was_impossible': False}),
#  Prediction(uid='218', iid='712', r_ui=3.0, est=3.2153741271271636, details={'was_impossible': False}),
#  Prediction(uid='653', iid='1244', r_ui=3.0, est=2.1547098497603576, details={'was_impossible': False}),
#  Prediction(uid='818', iid='245', r_ui=4.0, est=2.890859684354589, details={'was_impossible': False}),
#  ...]

# %% [markdown]
# # Add a Chatbot or GUI

# %%
import gradio as gr

def recommend_movies(user_id):
    # your recommendation logic here
    return ["Movie A", "Movie B"]

gr.Interface(fn=recommend_movies, inputs="text", outputs="text").launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://781cc18869f22c8ac3.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://781cc18869f22c8ac3.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
